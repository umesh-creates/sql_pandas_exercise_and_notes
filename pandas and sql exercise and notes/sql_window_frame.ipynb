# %% [markdown]
# <pre>Beginning                           End
# |-------------------------------------|
#
#  UNBOUNDED PRECEDING
#
#       2 PRECEDING
#
#             1 PRECEDING
#
#                   CURRENT ROW
#
#                          1 FOLLOWING
#
#                                2 FOLLOWING
#
#                                      UNBOUNDED FOLLOWING</pre>

# %% [markdown]
# AND => both should be true
